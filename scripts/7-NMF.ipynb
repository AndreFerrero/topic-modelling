# %%
# %%capture
# %run 3-tfidf-gensim.ipynb

# %%
import gensim
import numpy as np
from sklearn.decomposition import NMF

# %%
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=42)

# Fit NMF model
W = nmf_model.fit_transform(tfidf_matrix)  # Document-topic matrix
H = nmf_model.components_

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
feature_names = vectorizer.get_feature_names_out()  # Adjust this as per your setup

display_topics(nmf_model, feature_names, 10)  # Display top 10 words from each topic
# Out:
# Topic 0:
# god time way world day state car life government law
# Topic 1:
# card file program color version computer graphic window help video
# Topic 2:
# chip encryption clipper key government system algorithm escrow phone security
# Topic 3:
# game team year season baseball hockey league player division cup
# Topic 4:
# drive disk controller sale system mac ide apple tape bus

# %%
W = nmf_model.fit_transform(tfidf_matrix)

# Finding the index and the value of the highest value in each row
most_prominent_topics_indices = np.argmax(W, axis=1)
most_prominent_topics_values = np.max(W, axis=1)

# Calculate the percentage representation of the most prominent topic
most_prominent_topic_percentages = W[np.arange(len(W)), most_prominent_topics_indices] * 100

# Displaying the most prominent topic and its percentage for each document
for doc_index, (topic, percentage) in enumerate(zip(most_prominent_topics_indices, most_prominent_topic_percentages)):
    print(f"Document {doc_index} : Topic {topic} with percentage {percentage:.2f}%.")
# Out:
# Document 0 : Topic 0 with percentage 8.52%.
# Document 1 : Topic 0 with percentage 10.99%.
# Document 2 : Topic 0 with percentage 4.47%.
# Document 3 : Topic 0 with percentage 2.74%.
# Document 4 : Topic 0 with percentage 1.82%.
# Document 5 : Topic 0 with percentage 7.28%.
# Document 6 : Topic 0 with percentage 1.13%.
# Document 7 : Topic 0 with percentage 4.84%.
# Document 8 : Topic 0 with percentage 2.64%.
# Document 9 : Topic 0 with percentage 2.25%.
# Document 10 : Topic 0 with percentage 1.27%.
# Document 11 : Topic 1 with percentage 4.16%.
# Document 12 : Topic 0 with percentage 2.16%.
# Document 13 : Topic 0 with percentage 3.99%.
# Document 14 : Topic 0 with percentage 3.17%.
# Document 15 : Topic 0 with percentage 2.89%.
# Document 16 : Topic 0 with percentage 3.45%.
# Document 17 : Topic 0 with percentage 2.46%.
# Document 18 : Topic 0 with percentage 4.68%.
# Document 19 : Topic 0 with percentage 1.21%.
# Document 20 : Topic 0 with percentage 1.12%.
# ...
